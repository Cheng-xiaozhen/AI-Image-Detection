# %%
import sys
import os
from pathlib import Path
sys.path.append(os.path.abspath(os.path.join(os.getcwd(),"..")))
from utils.dataset_builder import ForgeryImageDataset, build_datasets_index,build_image_index

# %%
root_dir = "/home/chengxiaozhen/data/Benchmark"
root_path = Path(root_dir)
samples = build_datasets_index(root_path)
print(f"Total samples found: {len(samples)}")
# Out:
# Total samples found: 335477
